# %%
import pandas as pd

# %%
global_model_on_nodes = pd.read_csv(r'/home/mzuziak/snap/snapd-desktop-integration/83/Documents/Forcha/archiver_from_01_23_2024__13_05_22/results/global_model_on_nodes.csv')
global_model_on_orchestrator = pd.read_csv(r'/home/mzuziak/snap/snapd-desktop-integration/83/Documents/Forcha/archiver_from_01_23_2024__13_05_22/results/global_model_on_orchestrator.csv')
local_model_on_nodes = pd.read_csv(r'/home/mzuziak/snap/snapd-desktop-integration/83/Documents/Forcha/archiver_from_01_23_2024__13_05_22/results/local_model_on_nodes.csv')
training_metrics = pd.read_csv(r'/home/mzuziak/snap/snapd-desktop-integration/83/Documents/Forcha/archiver_from_01_23_2024__13_05_22/results/training_metrics.csv')

# %%
global_model_on_orchestrator[['loss', 'accuracy']].plot()
# Out:
# <Axes: >

# %%
results[['accuracy', 'loss']].plot()

# %%
local_results = pd.read_csv(f'/home/mzuziak/snap/snapd-desktop-integration/83/Documents/Forcha/forcha/tests/end_to_end/correctness/fedopt/archiver_from_01_03_2024__16_36_11/results/central_on_local_results.csv')
local_results.head()

# %%
local_results[local_results['node'] == 9][['loss', 'accuracy']].plot()
