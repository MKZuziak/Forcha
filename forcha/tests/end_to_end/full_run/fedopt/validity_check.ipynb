# %%
import pandas as pd

# %%
global_model_on_nodes = pd.read_csv(r'/home/maciejzuziak/raid/documents/Forcha/forcha/tests/end_to_end/full_run/fedopt/archiver_from_01_24_2024__13_17_19/results/global_model_on_nodes.csv')
global_model_on_orchestrator = pd.read_csv(r'/home/maciejzuziak/raid/documents/Forcha/forcha/tests/end_to_end/full_run/fedopt/archiver_from_01_24_2024__13_17_19/results/global_model_on_orchestrator.csv')
local_model_on_nodes = pd.read_csv(r'/home/maciejzuziak/raid/documents/Forcha/forcha/tests/end_to_end/full_run/fedopt/archiver_from_01_24_2024__13_17_19/results/local_model_on_nodes.csv')
training_metrics = pd.read_csv(r'/home/maciejzuziak/raid/documents/Forcha/forcha/tests/end_to_end/full_run/fedopt/archiver_from_01_24_2024__13_17_19/results/training_metrics.csv')

# %%
global_model_on_orchestrator[['loss', 'accuracy']].plot()
# Out:
# <Axes: >

# %%
global_model_on_nodes.groupby('node')[['loss', 'accuracy']].plot()
# Out:
# node
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# 2    Axes(0.125,0.11;0.775x0.77)
# 3    Axes(0.125,0.11;0.775x0.77)
# 4    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
training_metrics.groupby('node_id')[['loss', 'accuracy']].plot()
# Out:
# node_id
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# 2    Axes(0.125,0.11;0.775x0.77)
# 3    Axes(0.125,0.11;0.775x0.77)
# 4    Axes(0.125,0.11;0.775x0.77)
# dtype: object
